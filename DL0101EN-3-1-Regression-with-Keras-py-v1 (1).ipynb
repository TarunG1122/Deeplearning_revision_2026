# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean the Data Set</a>
# 2. <a href="#item32">Import Keras Packages</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean the  Data Set

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# !pip install numpy pandas keras
# Out:
# Requirement already satisfied: numpy in c:\users\2025\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: pandas in c:\users\2025\anaconda3\lib\site-packages (2.3.3)
# Collecting keras
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\2025\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\2025\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\2025\anaconda3\lib\site-packages (from pandas) (2025.2)
# Collecting absl-py (from keras)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: rich in c:\users\2025\anaconda3\lib\site-packages (from keras) (14.2.0)
# Collecting namex (from keras)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Requirement already satisfied: h5py in c:\users\2025\anaconda3\lib\site-packages (from keras) (3.15.1)
# Collecting optree (from keras)
#   Downloading optree-0.19.0-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: packaging in c:\users\2025\anaconda3\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\2025\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\2025\anaconda3\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\2025\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\2025\anaconda3\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\2025\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading keras-3.14.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.7 MB/s  0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl (212 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp313-cp313-win_amd64.whl (337 kB)
# Installing collected packages: namex, optree, ml-dtypes, absl-py, keras
#
#    -------- ------------------------------- 1/5 [optree]
#    ------------------------ --------------- 3/5 [absl-py]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    -------------------------------- ------- 4/5 [keras]
#    ---------------------------------------- 5/5 [keras]
#
# Successfully installed absl-py-2.4.0 keras-3.14.0 ml-dtypes-0.5.4 namex-0.1.0 optree-0.19.0
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\2025\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\2025\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\2025\anaconda3\Lib\site-packages)

# %%
pip install tensorflow numpy pandas
# Out:
# Requirement already satisfied: tensorflow in c:\users\2025\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: numpy in c:\users\2025\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: pandas in c:\users\2025\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\2025\anaconda3\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\2025\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\2025\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\2025\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\2025\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\2025\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\2025\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\2025\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\2025\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\2025\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\2025\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\2025\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\2025\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\2025\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\2025\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\2025\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\2025\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\2025\anaconda3\Lib\site-packages)

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %%
n_cols
# Out:
# 8

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 62ms/step - loss: 1607.2632 - val_loss: 1108.8340
# Epoch 2/100
# 23/23 - 0s - 6ms/step - loss: 1449.6503 - val_loss: 964.1107
# Epoch 3/100
# 23/23 - 0s - 6ms/step - loss: 1180.3085 - val_loss: 745.7155
# Epoch 4/100
# 23/23 - 0s - 7ms/step - loss: 810.4037 - val_loss: 496.1296
# Epoch 5/100
# 23/23 - 0s - 7ms/step - loss: 469.3042 - val_loss: 300.6441
# Epoch 6/100
# 23/23 - 0s - 6ms/step - loss: 301.9046 - val_loss: 213.9497
# Epoch 7/100
# 23/23 - 0s - 7ms/step - loss: 252.8498 - val_loss: 186.0366
# Epoch 8/100
# 23/23 - 0s - 7ms/step - loss: 231.5140 - val_loss: 175.9652
# Epoch 9/100
# 23/23 - 0s - 6ms/step - loss: 216.7476 - val_loss: 169.6409
# Epoch 10/100
# 23/23 - 0s - 7ms/step - loss: 205.7356 - val_loss: 165.4127
# Epoch 11/100
# 23/23 - 0s - 8ms/step - loss: 197.4461 - val_loss: 164.7452
# Epoch 12/100
# 23/23 - 0s - 7ms/step - loss: 190.4206 - val_loss: 162.6804
# Epoch 13/100
# 23/23 - 0s - 7ms/step - loss: 184.8468 - val_loss: 161.5857
# Epoch 14/100
# 23/23 - 0s - 7ms/step - loss: 180.5779 - val_loss: 157.1076
# Epoch 15/100
# 23/23 - 0s - 6ms/step - loss: 176.2411 - val_loss: 158.9979
# Epoch 16/100
# 23/23 - 0s - 6ms/step - loss: 171.7440 - val_loss: 157.9352
# Epoch 17/100
# 23/23 - 0s - 7ms/step - loss: 168.2776 - val_loss: 155.1751
# Epoch 18/100
# 23/23 - 0s - 7ms/step - loss: 165.0851 - val_loss: 155.3436
# Epoch 19/100
# 23/23 - 0s - 6ms/step - loss: 161.9763 - val_loss: 153.4259
# Epoch 20/100
# 23/23 - 0s - 6ms/step - loss: 159.4064 - val_loss: 153.0068
# Epoch 21/100
# 23/23 - 0s - 7ms/step - loss: 157.0847 - val_loss: 152.6752
# Epoch 22/100
# 23/23 - 0s - 6ms/step - loss: 154.4601 - val_loss: 151.2591
# Epoch 23/100
# 23/23 - 0s - 6ms/step - loss: 152.5221 - val_loss: 152.4046
# Epoch 24/100
# 23/23 - 0s - 6ms/step - loss: 150.6200 - val_loss: 152.4904
# Epoch 25/100
# 23/23 - 0s - 6ms/step - loss: 148.7008 - val_loss: 151.6494
# Epoch 26/100
# 23/23 - 0s - 6ms/step - loss: 147.0808 - val_loss: 155.6354
# Epoch 27/100
# 23/23 - 0s - 7ms/step - loss: 144.6287 - val_loss: 153.2427
# Epoch 28/100
# 23/23 - 0s - 7ms/step - loss: 143.8248 - val_loss: 151.2440
# Epoch 29/100
# 23/23 - 0s - 7ms/step - loss: 141.9070 - val_loss: 154.7783
# Epoch 30/100
# 23/23 - 0s - 11ms/step - loss: 139.6085 - val_loss: 153.3197
# Epoch 31/100
# 23/23 - 0s - 7ms/step - loss: 137.8367 - val_loss: 155.3794
# Epoch 32/100
# 23/23 - 0s - 7ms/step - loss: 136.7858 - val_loss: 153.8857
# Epoch 33/100
# 23/23 - 0s - 6ms/step - loss: 135.3794 - val_loss: 155.4291
# Epoch 34/100
# 23/23 - 0s - 6ms/step - loss: 133.8297 - val_loss: 156.1868
# Epoch 35/100
# 23/23 - 0s - 7ms/step - loss: 132.0649 - val_loss: 155.0461
# Epoch 36/100
# 23/23 - 0s - 7ms/step - loss: 130.8808 - val_loss: 154.7141
# Epoch 37/100
# 23/23 - 0s - 6ms/step - loss: 129.3148 - val_loss: 155.7391
# Epoch 38/100
# 23/23 - 0s - 8ms/step - loss: 128.8107 - val_loss: 158.4161
# Epoch 39/100
# 23/23 - 0s - 6ms/step - loss: 126.8635 - val_loss: 155.1262
# Epoch 40/100
# 23/23 - 0s - 7ms/step - loss: 125.5899 - val_loss: 156.0692
# Epoch 41/100
# 23/23 - 0s - 6ms/step - loss: 124.9276 - val_loss: 157.7755
# Epoch 42/100
# 23/23 - 0s - 6ms/step - loss: 123.0646 - val_loss: 157.6298
# Epoch 43/100
# 23/23 - 0s - 6ms/step - loss: 122.0246 - val_loss: 154.1440
# Epoch 44/100
# 23/23 - 0s - 7ms/step - loss: 119.7346 - val_loss: 157.7579
# Epoch 45/100
# 23/23 - 0s - 7ms/step - loss: 118.3766 - val_loss: 158.2084
# Epoch 46/100
# 23/23 - 0s - 7ms/step - loss: 116.6092 - val_loss: 154.0310
# Epoch 47/100
# 23/23 - 0s - 6ms/step - loss: 114.8312 - val_loss: 158.8145
# Epoch 48/100
# 23/23 - 0s - 7ms/step - loss: 113.8704 - val_loss: 153.0442
# Epoch 49/100
# 23/23 - 0s - 6ms/step - loss: 112.8561 - val_loss: 158.7734
# Epoch 50/100
# 23/23 - 0s - 6ms/step - loss: 110.6411 - val_loss: 152.9101
# Epoch 51/100
# 23/23 - 0s - 6ms/step - loss: 108.8177 - val_loss: 158.0912
# Epoch 52/100
# 23/23 - 0s - 7ms/step - loss: 106.7067 - val_loss: 152.2434
# Epoch 53/100
# 23/23 - 0s - 7ms/step - loss: 104.3960 - val_loss: 154.4221
# Epoch 54/100
# 23/23 - 0s - 6ms/step - loss: 102.8928 - val_loss: 147.8151
# Epoch 55/100
# 23/23 - 0s - 7ms/step - loss: 101.4129 - val_loss: 151.9636
# Epoch 56/100

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# <hr>
#
# Copyright &copy; [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://opensource.org/license/mit).
